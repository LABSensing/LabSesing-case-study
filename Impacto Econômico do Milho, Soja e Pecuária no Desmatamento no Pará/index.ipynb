# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
#a
df_milho_rs = pd.read_excel("Producao-Milhos/Produção - milho(R$).xls")
df_milho_rs.head(27)
# Out:
#    Sigla  Codigo               Estado          1999          2000  \
# 0     AC      12                 Acre  1.890494e+04  2.498862e+04
# 1     AL      27              Alagoas  1.001480e+04  1.741016e+04
# 2     AM      13             Amazonas  1.257244e+04  1.288772e+04
# 3     AP      16                Amapá  6.635878e+02  6.797185e+02
# 4     BA      29                Bahia  3.751054e+05  5.017268e+05
# 5     CE      23                Ceará  2.103538e+05  3.082783e+05
# 6     DF      53     Distrito Federal  3.791741e+04  5.580912e+04
# 7     ES      32       Espírito Santo  5.781818e+04  6.007141e+04
# 8     GO      52                Goiás  9.709671e+05  1.450633e+06
# 9     MA      21             Maranhão  9.656050e+04  1.317080e+05
# 10    MG      31         Minas Gerais  1.468290e+06  1.907485e+06
# 11    MS      50   Mato Grosso do Sul  5.790661e+05  4.158691e+05
# 12    MT      51          Mato Grosso  2.874550e+05  5.262078e+05
# 13    PA      15                 Pará  2.870529e+05  2.782834e+05
# 14    PB      25              Paraíba  9.402967e+03  6.115716e+04
# 15    PE      26           Pernambuco  1.872316e+04  6.926343e+04
# 16    PI      22                Piauí  9.872656e+04  9.644433e+04
# 17    PR      41               Paraná  2.992350e+06  2.941949e+06
# 18    RJ      33       Rio de Janeiro  1.525069e+04  1.620691e+04
# 19    RN      24  Rio Grande do Norte  6.981662e+03  3.089678e+04
# 20    RO      11             Rondônia  6.901205e+04  8.056594e+04
# 21    RR      14              Roraima  1.859524e+04  1.760812e+04
# 22    RS      43    Rio Grande do Sul  1.204064e+06  1.653368e+06
# 23    SC      42       Santa Catarina  1.064396e+06  1.395122e+06
# 24    SE      28              Sergipe  5.151990e+04  3.611450e+04
# 25    SP      35            São Paulo  1.490755e+06  1.484705e+06
# 26    TO      17            Tocantins  3.643467e+04  5.309877e+04
#
#             2001          2002          2003          2004          2005  ...  \
# 0   2.095480e+04  2.929978e+04  3.578663e+04  2.694729e+04  2.700647e+04  ...
# 1   1.351236e+04  3.633074e+04  7.552958e+03  1.649166e+04  1.710002e+04  ...
# 2   9.962187e+03  1.003256e+04  1.204044e+04  1.190360e+04  1.845934e+04  ...
# 3   1.040857e+03  1.229136e+03  6.027713e+02  6.474891e+02  9.033323e+02  ...
# 4   3.998350e+05  6.388598e+05  7.080565e+05  7.111640e+05  5.836606e+05  ...
# 5   1.258227e+05  3.864900e+05  4.696721e+05  2.247637e+05  1.664793e+05  ...
# 6   4.063513e+04  6.714462e+04  9.606044e+04  9.217061e+04  7.670845e+04  ...
# 7   5.277706e+04  7.798266e+04  9.034077e+04  7.199028e+04  6.990469e+04  ...
# 8   1.105786e+06  1.503333e+06  1.626976e+06  1.383363e+06  9.930168e+05  ...
# 9   1.316840e+05  1.798983e+05  2.305267e+05  1.970051e+05  1.758837e+05  ...
# 10  1.352121e+06  2.353979e+06  2.669694e+06  2.603272e+06  2.585910e+06  ...
# 11  5.665159e+05  5.829541e+05  1.258678e+06  8.274061e+05  3.953028e+05  ...
# 12  4.069624e+05  1.055972e+06  1.453676e+06  1.014830e+06  1.149849e+06  ...
# 13  2.506566e+05  2.716029e+05  3.836773e+05  3.555040e+05  2.872769e+05  ...
# 14  4.063304e+03  5.562456e+04  9.136981e+04  3.877363e+04  3.215460e+04  ...
# 15  1.098636e+04  7.265958e+04  5.302390e+04  3.939021e+04  6.015071e+04  ...
# 16  6.564697e+04  4.592066e+04  1.453428e+05  7.498820e+04  9.252827e+04  ...
# 17  3.628124e+06  4.080768e+06  6.017576e+06  4.681980e+06  3.245177e+06  ...
# 18  1.171433e+04  1.219447e+04  1.589018e+04  1.347210e+04  1.443749e+04  ...
# 19  4.084163e+03  4.655517e+04  4.980024e+04  3.998670e+04  1.362191e+04  ...
# 20  5.497350e+04  1.264604e+05  1.436661e+05  9.411463e+04  9.374662e+04  ...
# 21  1.617604e+04  1.935461e+04  2.367792e+04  2.002889e+04  1.726113e+04  ...
# 22  2.319819e+06  1.915449e+06  2.641083e+06  1.684672e+06  6.802567e+05  ...
# 23  1.112065e+06  1.266285e+06  1.979704e+06  1.534991e+06  1.076440e+06  ...
# 24  2.333062e+04  3.048332e+04  4.893771e+04  6.059818e+04  6.765930e+04  ...
# 25  1.391711e+06  2.006090e+06  2.159625e+06  2.016096e+06  1.596807e+06  ...
# 26  5.670478e+04  6.830726e+04  1.042212e+05  8.245210e+04  6.881436e+04  ...
#
#             2011          2012          2013          2014          2015  \
# 0   3.826859e+04  4.702432e+04  5.294478e+04  4.408378e+04  3.969982e+04
# 1   1.509713e+04  7.765829e+02  3.381147e+03  4.173058e+03  7.536855e+03
# 2   2.077575e+04  2.156215e+04  1.751752e+04  1.632191e+04  1.275093e+04
# 3   1.487279e+03  1.152901e+03  7.915861e+02  7.509586e+02  6.809915e+02
# 4   7.455101e+05  7.197564e+05  7.015824e+05  8.314137e+05  7.932358e+05
# 5   4.793157e+05  6.278861e+04  6.241677e+04  1.604027e+05  5.645989e+04
# 6   1.015366e+05  1.275401e+05  1.368943e+05  1.765771e+05  1.278262e+05
# 7   4.315049e+04  3.483590e+04  2.891557e+04  2.643477e+04  1.180591e+04
# 8   1.918357e+06  2.587198e+06  2.034518e+06  2.106118e+06  2.238045e+06
# 9   3.082333e+05  3.161556e+05  5.167132e+05  4.524466e+05  4.059457e+05
# 10  2.718340e+06  2.584882e+06  2.439567e+06  2.226533e+06  2.057133e+06
# 11  1.213936e+06  2.008793e+06  1.525415e+06  1.528372e+06  2.096980e+06
# 12  2.672511e+06  3.840922e+06  3.759601e+06  2.743099e+06  3.920653e+06
# 13  2.716385e+05  2.644727e+05  2.790846e+05  2.259175e+05  2.666552e+05
# 14  3.172493e+04  3.939362e+03  1.392555e+04  1.300752e+04  4.907528e+03
# 15  5.712962e+04  1.133058e+04  1.223896e+04  2.362643e+04  1.363286e+04
# 16  3.147742e+05  3.426493e+05  2.022292e+05  3.618794e+05  3.134673e+05
# 17  4.328523e+06  5.743466e+06  4.637940e+06  3.985872e+06  3.802471e+06
# 18  8.580244e+03  7.138918e+03  5.747154e+03  4.583945e+03  4.064004e+03
# 19  2.607032e+04  1.282901e+03  7.000963e+03  7.575977e+03  2.097152e+03
# 20  1.259433e+05  1.749484e+05  1.086056e+05  1.454794e+05  2.092633e+05
# 21  7.135432e+03  7.066221e+03  8.283412e+03  7.964734e+03  8.041598e+03
# 22  2.154227e+06  1.185409e+06  1.879251e+06  1.601019e+06  1.502197e+06
# 23  1.334496e+06  9.862672e+05  1.107609e+06  9.459872e+05  8.289011e+05
# 24  1.989908e+05  1.441348e+05  2.309299e+05  2.436020e+05  1.850528e+05
# 25  1.243125e+06  1.577139e+06  1.373602e+06  1.135002e+06  1.300081e+06
# 26  1.431462e+05  1.398311e+05  1.068037e+05  1.450058e+05  1.958897e+05
#
#             2016          2017          2018          2019          2020
# 0   3.682917e+04  3.786428e+04  3.314050e+04  3.089437e+04  3.755522e+04
# 1   8.125826e+03  1.122013e+04  9.889093e+03  1.700834e+04  3.381848e+04
# 2   6.198567e+03  5.769165e+03  3.934673e+03  3.177370e+03  3.391611e+03
# 3   5.906116e+02  5.947845e+02  4.269053e+02  4.590471e+02  5.124092e+02
# 4   7.022042e+05  5.268243e+05  6.727102e+05  5.864947e+05  1.130002e+06
# 5   6.694655e+04  1.427214e+05  1.711826e+05  1.695457e+05  2.799448e+05
# 6   1.224869e+05  1.315679e+05  1.062139e+05  1.251327e+05  2.056471e+05
# 7   1.971920e+04  1.628988e+04  1.726712e+04  1.521654e+04  1.960559e+04
# 8   2.350322e+06  2.161648e+06  2.447576e+06  3.168265e+06  3.989370e+06
# 9   3.244697e+05  4.051566e+05  4.226239e+05  5.016058e+05  8.077675e+05
# 10  2.655003e+06  1.949920e+06  2.050106e+06  2.489053e+06  3.219409e+06
# 11  2.078161e+06  1.737122e+06  2.080791e+06  2.424842e+06  3.921082e+06
# 12  4.902669e+06  4.261712e+06  5.397833e+06  6.650319e+06  1.009029e+07
# 13  2.911303e+05  2.626249e+05  2.633057e+05  2.653719e+05  3.469570e+05
# 14  7.300492e+03  1.153099e+04  2.413508e+04  1.674988e+04  3.821802e+04
# 15  7.982455e+03  1.796347e+04  2.249363e+04  1.229257e+04  4.607725e+04
# 16  3.011980e+05  4.954635e+05  5.132930e+05  5.516802e+05  8.561049e+05
# 17  4.867159e+06  3.671320e+06  3.684059e+06  4.560720e+06  6.683465e+06
# 18  4.996409e+03  3.531380e+03  3.025230e+03  3.461114e+03  3.417996e+03
# 19  1.912034e+03  2.232278e+03  1.136013e+04  1.266060e+04  1.469417e+04
# 20  2.089319e+05  2.043960e+05  1.845185e+05  3.132364e+05  3.967404e+05
# 21  1.118292e+04  2.038483e+04  1.849337e+04  2.099705e+04  4.713795e+04
# 22  1.864206e+06  1.549706e+06  1.365399e+06  1.751574e+06  1.609734e+06
# 23  1.039424e+06  7.941652e+05  8.299009e+05  8.913008e+05  1.018685e+06
# 24  6.719270e+04  2.757714e+05  4.263958e+04  3.191737e+05  4.963214e+05
# 25  1.747370e+06  1.254525e+06  1.448979e+06  1.529286e+06  2.290706e+06
# 26  2.050704e+05  2.297471e+05  2.325234e+05  2.988003e+05  6.205133e+05
#
# [27 rows x 25 columns]

# %%
# Filtrar apenas as linhas onde o Estado é "Pará"
df_para_milho_rs = df_milho_rs[df_milho_rs["Estado"] == "Pará"]
df_para_milho_rs.head(1)
# Out:
#    Sigla  Codigo Estado           1999           2000           2001  \
# 13    PA      15   Pará  287052.857872  278283.391781  250656.630044
#
#              2002           2003           2004           2005  ...  \
# 13  271602.855672  383677.276371  355503.965805  287276.941858  ...
#
#              2011           2012           2013           2014           2015  \
# 13  271638.500808  264472.676169  279084.628294  225917.546962  266655.164783
#
#              2016           2017           2018           2019           2020
# 13  291130.285511  262624.904042  263305.677122  265371.907309  346956.983994
#
# [1 rows x 25 columns]

# %% [markdown]
# ## Cálculo da Produção de Milho por km² (em milhões de R$)
#
# A fórmula utilizada para calcular a produção de milho por km² em milhões de reais é:
#
# $$
# \text{Produção de Milho(R\$) por km² no ano X} = \left( \frac{\text{Produção de Milho (R\$) no ano X}}{\text{Área total (km²)}} \right)
# $$
#
# Onde:
#
# - **Produção de Milho (R$) no ano X**: Valor da produção de milho em reais para um determinado ano.
# - **Área total (km²)**: Área total considerada no cálculo (**1.247.954,666 km²**).

# %%
para_km = 1247954.666

colunas_producao = df_para_milho_rs.columns[3:]
for i , linha in df_para_milho_rs.iterrows():
    if i >= 3:
        producao_milho_para_por_km2 = (linha[colunas_producao]/para_km)

# %%
df_para_milho_rs.head()
# Out:
#    Sigla  Codigo Estado           1999           2000           2001  \
# 13    PA      15   Pará  287052.857872  278283.391781  250656.630044
#
#              2002           2003           2004           2005  ...  \
# 13  271602.855672  383677.276371  355503.965805  287276.941858  ...
#
#              2011           2012           2013           2014           2015  \
# 13  271638.500808  264472.676169  279084.628294  225917.546962  266655.164783
#
#              2016           2017           2018           2019           2020
# 13  291130.285511  262624.904042  263305.677122  265371.907309  346956.983994
#
# [1 rows x 25 columns]

# %%
# Inicializando uma lista vazia para armazenar os valores do dicionário
dados = []

# Preenchendo os dados com um for
for valor in producao_milho_para_por_km2:
    dados.append({'Produção Milho (R$)/km²': valor})

# Criando o DataFrame com os dados preenchidos
df_producao_milho_km = pd.DataFrame(dados)

# Exibindo o DataFrame invertido
print(df_producao_milho_km.head(22))
# Out:
#     Produção Milho (R$)/km²
# 0                  0.230019
# 1                  0.222992
# 2                  0.200854
# 3                  0.217638
# 4                  0.307445
# 5                  0.284869
# 6                  0.230198
# 7                  0.228860
# 8                  0.106208
# 9                  0.107539
# 10                 0.110131
# 11                 0.091311
# 12                 0.217667
# 13                 0.211925
# 14                 0.223634
# 15                 0.181030
# 16                 0.213674
# 17                 0.233286
# 18                 0.210444
# 19                 0.210990
# 20                 0.212645
# 21                 0.278021

# %%
for i, row in df_producao_milho_km.iterrows():
    print(f"{i}) {row}")
# Out:
# 0) Produção Milho (R$)/km²    0.230019
# Name: 0, dtype: float64
# 1) Produção Milho (R$)/km²    0.222992
# Name: 1, dtype: float64
# 2) Produção Milho (R$)/km²    0.200854
# Name: 2, dtype: float64
# 3) Produção Milho (R$)/km²    0.217638
# Name: 3, dtype: float64
# 4) Produção Milho (R$)/km²    0.307445
# Name: 4, dtype: float64
# 5) Produção Milho (R$)/km²    0.284869
# Name: 5, dtype: float64
# 6) Produção Milho (R$)/km²    0.230198
# Name: 6, dtype: float64
# 7) Produção Milho (R$)/km²    0.22886
# Name: 7, dtype: float64
# 8) Produção Milho (R$)/km²    0.106208
# Name: 8, dtype: float64
# 9) Produção Milho (R$)/km²    0.107539
# Name: 9, dtype: float64
# 10) Produção Milho (R$)/km²    0.110131
# Name: 10, dtype: float64
# 11) Produção Milho (R$)/km²    0.091311
# Name: 11, dtype: float64
# 12) Produção Milho (R$)/km²    0.217667
# Name: 12, dtype: float64
# 13) Produção Milho (R$)/km²    0.211925
# Name: 13, dtype: float64
# 14) Produção Milho (R$)/km²    0.223634
# Name: 14, dtype: float64
# 15) Produção Milho (R$)/km²    0.18103
# Name: 15, dtype: float64
# 16) Produção Milho (R$)/km²    0.213674
# Name: 16, dtype: float64
# 17) Produção Milho (R$)/km²    0.233286
# Name: 17, dtype: float64
# 18) Produção Milho (R$)/km²    0.210444
# Name: 18, dtype: float64
# 19) Produção Milho (R$)/km²    0.21099
# Name: 19, dtype: float64
# 20) Produção Milho (R$)/km²    0.212645
# Name: 20, dtype: float64
# 21) Produção Milho (R$)/km²    0.278021
# Name: 21, dtype: float64

# %%
# Inicializando a lista para armazenar os valores a partir da posição 12
valores_filtrados = []

# Percorrendo o DataFrame a partir da linha 12 até o final
for index, row in df_producao_milho_km.iloc[12:].iterrows():
    valores_filtrados.append(row['Produção Milho (R$)/km²'])

# Exibindo a lista de valores filtrados
print(valores_filtrados)

print(len(valores_filtrados))
# Out:
# [0.21766696195711885, 0.21192490670923692, 0.22363362700417896, 0.1810302514322489, 0.2136737591899481, 0.2332859465516377, 0.2104442662843391, 0.2109897773499699, 0.21264547065576883, 0.2780205030253442]
# 10

# %%
df_desmatamento = pd.read_excel("PRODES(DESMATAMENTO)/desmatamento_1999_2020_PARA.xlsx")


# Exibir as primeiras linhas do DataFrame filtrado e ordenado
print(df_desmatamento.head(22))
# Out:
#     year  area km²    uf
# 0   2024      2362  Pará
# 1   2023      3299  Pará
# 2   2022      4162  Pará
# 3   2021      5238  Pará
# 4   2020      4899  Pará
# 5   2019      4172  Pará
# 6   2018      2744  Pará
# 7   2017      2433  Pará
# 8   2016      2992  Pará
# 9   2015      2153  Pará
# 10  2014      1887  Pará
# 11  2013      2346  Pará
# 12  2012      1741  Pará
# 13  2011      3008  Pará
# 14  2010      3770  Pará
# 15  2009      4281  Pará
# 16  2008      5607  Pará
# 17  2007      5526  Pará
# 18  2006      5659  Pará
# 19  2005      5899  Pará
# 20  2004      8870  Pará
# 21  2003      7145  Pará

# %%
df_desmatamento.dtypes
# Out:
# year         int64
# area km²     int64
# uf          object
# dtype: object

# %%
df_desmatamento['area km²'] = df_desmatamento['area km²'].astype(float)

# %%
df_desmatamento.dtypes
# Out:
# year          int64
# area km²    float64
# uf           object
# dtype: object

# %%
df_desmatamento.head(20)
# Out:
#     year  area km²    uf
# 0   2024    2362.0  Pará
# 1   2023    3299.0  Pará
# 2   2022    4162.0  Pará
# 3   2021    5238.0  Pará
# 4   2020    4899.0  Pará
# 5   2019    4172.0  Pará
# 6   2018    2744.0  Pará
# 7   2017    2433.0  Pará
# 8   2016    2992.0  Pará
# 9   2015    2153.0  Pará
# 10  2014    1887.0  Pará
# 11  2013    2346.0  Pará
# 12  2012    1741.0  Pará
# 13  2011    3008.0  Pará
# 14  2010    3770.0  Pará
# 15  2009    4281.0  Pará
# 16  2008    5607.0  Pará
# 17  2007    5526.0  Pará
# 18  2006    5659.0  Pará
# 19  2005    5899.0  Pará

# %%
# Criar uma cópia do DataFrame original
df_desmatamento_crescente = df_desmatamento.copy()

# Filtrar as linhas onde o ano é maior ou igual a 1990
df_desmatamento_crescente = df_desmatamento_crescente[df_desmatamento_crescente['year'] >= 1990]

# Ordenar o DataFrame pela coluna 'year' em ordem crescente
df_desmatamento_crescente = df_desmatamento_crescente.sort_values(by='year')

# Resetar os índices para começar do 0
df_desmatamento_crescente = df_desmatamento_crescente.reset_index(drop=True)

# Exibir o DataFrame final
print(df_desmatamento_crescente)
# Out:
#     year  area km²    uf
# 0   1990    4890.0  Pará
# 1   1991    3780.0  Pará
# 2   1992    3787.0  Pará
# 3   1993    4284.0  Pará
# 4   1994    4284.0  Pará
# 5   1995    7845.0  Pará
# 6   1996    6135.0  Pará
# 7   1997    4139.0  Pará
# 8   1998    5829.0  Pará
# 9   1999    5111.0  Pará
# 10  2000    6671.0  Pará
# 11  2001    5237.0  Pará
# 12  2002    7510.0  Pará
# 13  2003    7145.0  Pará
# 14  2004    8870.0  Pará
# 15  2005    5899.0  Pará
# 16  2006    5659.0  Pará
# 17  2007    5526.0  Pará
# 18  2008    5607.0  Pará
# 19  2009    4281.0  Pará
# 20  2010    3770.0  Pará
# 21  2011    3008.0  Pará
# 22  2012    1741.0  Pará
# 23  2013    2346.0  Pará
# 24  2014    1887.0  Pará
# 25  2015    2153.0  Pará
# 26  2016    2992.0  Pará
# 27  2017    2433.0  Pará
# 28  2018    2744.0  Pará
# 29  2019    4172.0  Pará
# 30  2020    4899.0  Pará
# 31  2021    5238.0  Pará
# 32  2022    4162.0  Pará
# 33  2023    3299.0  Pará
# 34  2024    2362.0  Pará

# %%
df_desmatamento_crescente.head(22)
# Out:
#     year  area km²    uf
# 0   1990    4890.0  Pará
# 1   1991    3780.0  Pará
# 2   1992    3787.0  Pará
# 3   1993    4284.0  Pará
# 4   1994    4284.0  Pará
# 5   1995    7845.0  Pará
# 6   1996    6135.0  Pará
# 7   1997    4139.0  Pará
# 8   1998    5829.0  Pará
# 9   1999    5111.0  Pará
# 10  2000    6671.0  Pará
# 11  2001    5237.0  Pará
# 12  2002    7510.0  Pará
# 13  2003    7145.0  Pará
# 14  2004    8870.0  Pará
# 15  2005    5899.0  Pará
# 16  2006    5659.0  Pará
# 17  2007    5526.0  Pará
# 18  2008    5607.0  Pará
# 19  2009    4281.0  Pará
# 20  2010    3770.0  Pará
# 21  2011    3008.0  Pará

# %%
df_desmatamento_crescente.dtypes
# Out:
# year          int64
# area km²    float64
# uf           object
# dtype: object

# %%
df_desmatamento_crescente_1999_2021 = df_desmatamento_crescente[(df_desmatamento_crescente['year'] >= 1999) & (df_desmatamento_crescente['year'] <= 2020)]

# Exibir o DataFrame resultante
df_desmatamento_crescente_1999_2021
# Out:
#     year  area km²    uf
# 9   1999    5111.0  Pará
# 10  2000    6671.0  Pará
# 11  2001    5237.0  Pará
# 12  2002    7510.0  Pará
# 13  2003    7145.0  Pará
# 14  2004    8870.0  Pará
# 15  2005    5899.0  Pará
# 16  2006    5659.0  Pará
# 17  2007    5526.0  Pará
# 18  2008    5607.0  Pará
# 19  2009    4281.0  Pará
# 20  2010    3770.0  Pará
# 21  2011    3008.0  Pará
# 22  2012    1741.0  Pará
# 23  2013    2346.0  Pará
# 24  2014    1887.0  Pará
# 25  2015    2153.0  Pará
# 26  2016    2992.0  Pará
# 27  2017    2433.0  Pará
# 28  2018    2744.0  Pará
# 29  2019    4172.0  Pará
# 30  2020    4899.0  Pará

# %%
df_desmatamento_crescente_1999_2021.reset_index(drop=True, inplace=True)

# Exibir o DataFrame resultante
df_desmatamento_crescente_1999_2021
# Out:
#     year  area km²    uf
# 0   1999    5111.0  Pará
# 1   2000    6671.0  Pará
# 2   2001    5237.0  Pará
# 3   2002    7510.0  Pará
# 4   2003    7145.0  Pará
# 5   2004    8870.0  Pará
# 6   2005    5899.0  Pará
# 7   2006    5659.0  Pará
# 8   2007    5526.0  Pará
# 9   2008    5607.0  Pará
# 10  2009    4281.0  Pará
# 11  2010    3770.0  Pará
# 12  2011    3008.0  Pará
# 13  2012    1741.0  Pará
# 14  2013    2346.0  Pará
# 15  2014    1887.0  Pará
# 16  2015    2153.0  Pará
# 17  2016    2992.0  Pará
# 18  2017    2433.0  Pará
# 19  2018    2744.0  Pará
# 20  2019    4172.0  Pará
# 21  2020    4899.0  Pará

# %%
# Concatenar os dois DataFrames por linhas (verticalmente), ignorando os índices
df_producao_milho_rs_para_km = pd.concat([df_desmatamento_crescente_1999_2021, df_producao_milho_km], axis=1)

# Exibir o DataFrame resultante
df_producao_milho_rs_para_km.head(35)
# Out:
#     year  area km²    uf  Produção Milho (R$)/km²
# 0   1999    5111.0  Pará                 0.230019
# 1   2000    6671.0  Pará                 0.222992
# 2   2001    5237.0  Pará                 0.200854
# 3   2002    7510.0  Pará                 0.217638
# 4   2003    7145.0  Pará                 0.307445
# 5   2004    8870.0  Pará                 0.284869
# 6   2005    5899.0  Pará                 0.230198
# 7   2006    5659.0  Pará                 0.228860
# 8   2007    5526.0  Pará                 0.106208
# 9   2008    5607.0  Pará                 0.107539
# 10  2009    4281.0  Pará                 0.110131
# 11  2010    3770.0  Pará                 0.091311
# 12  2011    3008.0  Pará                 0.217667
# 13  2012    1741.0  Pará                 0.211925
# 14  2013    2346.0  Pará                 0.223634
# 15  2014    1887.0  Pará                 0.181030
# 16  2015    2153.0  Pará                 0.213674
# 17  2016    2992.0  Pará                 0.233286
# 18  2017    2433.0  Pará                 0.210444
# 19  2018    2744.0  Pará                 0.210990
# 20  2019    4172.0  Pará                 0.212645
# 21  2020    4899.0  Pará                 0.278021

# %%
with pd.ExcelWriter("Produção de Milho(R$)-km + desmatamento(Pará).xlsx") as writer:
    df_producao_milho_rs_para_km.to_excel(writer, index=False)

# %%
df_producao_milho_rs_para_km = pd.read_excel("Produção de Milho(R$)-km + desmatamento(Pará).xlsx")

# %%
print(df_producao_milho_rs_para_km.head(35))
# Out:
#     year  area km²    uf  Produção Milho (R$)/km²
# 0   1999      5111  Pará                 0.230019
# 1   2000      6671  Pará                 0.222992
# 2   2001      5237  Pará                 0.200854
# 3   2002      7510  Pará                 0.217638
# 4   2003      7145  Pará                 0.307445
# 5   2004      8870  Pará                 0.284869
# 6   2005      5899  Pará                 0.230198
# 7   2006      5659  Pará                 0.228860
# 8   2007      5526  Pará                 0.106208
# 9   2008      5607  Pará                 0.107539
# 10  2009      4281  Pará                 0.110131
# 11  2010      3770  Pará                 0.091311
# 12  2011      3008  Pará                 0.217667
# 13  2012      1741  Pará                 0.211925
# 14  2013      2346  Pará                 0.223634
# 15  2014      1887  Pará                 0.181030
# 16  2015      2153  Pará                 0.213674
# 17  2016      2992  Pará                 0.233286
# 18  2017      2433  Pará                 0.210444
# 19  2018      2744  Pará                 0.210990
# 20  2019      4172  Pará                 0.212645
# 21  2020      4899  Pará                 0.278021

# %%
df_producao_milho_rs_para_km.dtypes
# Out:
# year                         int64
# area km²                     int64
# uf                          object
# Produção Milho (R$)/km²    float64
# dtype: object

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Exibindo as primeiras linhas para verificar os dados
print(df_producao_milho_rs_para_km.head())

# Criando o gráfico
plt.figure(figsize=(10, 6))

# Plotando a produção de milho (R$) por km² ao longo dos anos
plt.plot(
    df_producao_milho_rs_para_km['year'], 
    df_producao_milho_rs_para_km['Produção Milho (R$)/km²'], 
    marker='o', 
    linestyle='-', 
    color='b'
)

# Adicionando títulos e rótulos
plt.title("Produção de Milho (R$) por km² ao longo dos anos", fontsize=14)
plt.xlabel("Ano", fontsize=12)
plt.ylabel("Produção (R$) por km²", fontsize=12) 
plt.grid(True)

# Formatando o eixo y para exibir valores com duas casas decimais e separadores de milhares
formatter = ticker.FuncFormatter(lambda x, pos: f'{x:.3f}')
plt.gca().yaxis.set_major_formatter(formatter)


# Exibindo o gráfico
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#    year  area km²    uf  Produção Milho (R$)/km²
# 0  1999      5111  Pará                 0.230019
# 1  2000      6671  Pará                 0.222992
# 2  2001      5237  Pará                 0.200854
# 3  2002      7510  Pará                 0.217638
# 4  2003      7145  Pará                 0.307445

# %%
# Exibindo as primeiras linhas para verificar os dados
df_producao_milho_rs_para_km.head()

# Criando o gráfico para o desmatamento
plt.figure(figsize=(10, 6))

# Plotando o desmatamento (área km²)
plt.plot(df_producao_milho_rs_para_km['year'], df_producao_milho_rs_para_km['area km²'], marker='s', linestyle='-', color='r')

# Adicionando títulos e rótulos
plt.title("Área Desmatada ao longo dos anos", fontsize=14)
plt.xlabel("Ano", fontsize=12)
plt.ylabel("Área Desmatada (km²)", fontsize=12, color='r')
plt.grid(True)

# Exibindo o gráfico
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Criando a figura e os eixos
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plotando o desmatamento (área km²) no eixo esquerdo
ax1.plot(df_producao_milho_rs_para_km['year'], df_producao_milho_rs_para_km['area km²'], 
         marker='s', linestyle='-', color='r', label="Área Desmatada (km²)")
ax1.set_xlabel("Ano", fontsize=12)
ax1.set_ylabel("Área Desmatada (km²)", fontsize=12, color='r')
ax1.tick_params(axis='y', labelcolor='r')

# Criando um segundo eixo Y para a produção de milho
ax2 = ax1.twinx()
ax2.plot(df_producao_milho_rs_para_km['year'], df_producao_milho_rs_para_km['Produção Milho (R$)/km²'], 
         marker='o', linestyle='-', color='b', label="Produção Milho (R$)/km²")
ax2.set_ylabel("Produção Milho (R$)/km²", fontsize=12, color='b')
ax2.tick_params(axis='y', labelcolor='b')

# Adicionando o título e a grade
plt.title("Produção de Milho (R$) por km² e Área Desmatada ao longo dos anos", fontsize=14)
ax1.grid(True)

# Formatando o eixo y para exibir valores com duas casas decimais e separadores de milhares
formatter = ticker.FuncFormatter(lambda x, pos: f'{x:.3f}')
plt.gca().yaxis.set_major_formatter(formatter)

# Exibindo o gráfico
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_gado_rs = pd.read_excel("Rebanho-bovino/Cabeca-Gado(R$).xls")
df_gado_rs.head()
# Out:
#   Sigla  Codigo     State     1999     2000     2001     2002      2003  \
# 0    AC      12      Acre   929999  1033311  1672598  1817467   1874804
# 1    AL      27   Alagoas   815472   778750   843240   816067    825121
# 2    AM      13  Amazonas   826025   843254   863736   894856   1121009
# 3    AP      16     Amapá    76734    82822    87197    83901     81674
# 4    BA      29     Bahia  9170680  9556752  9855828  9856290  10146529
#
#        2004      2005  ...      2011      2012      2013      2014      2015  \
# 0   2062690   2313185  ...   2549497   2634467   2697489   2799673   2916207
# 1    893922    985422  ...   1268304   1221266   1251723   1253121   1255696
# 2   1156723   1197171  ...   1439597   1445739   1470537   1405208   1293325
# 3     82243     96599  ...    127499    142825    154967    167529     89682
# 4  10466163  10463098  ...  10667903  10250975  10828409  10824134  10758372
#
#        2016      2017     2018      2019     2020
# 0   2998969   2895028  3303633   3509682  3802112
# 1   1189985   1208404  1247619   1233394  1290414
# 2   1315821   1343574  1376210   1455842  1437809
# 3     76379     66921    55422     54296    54684
# 4  10363291  10037814  9923931  10214863  9748632
#
# [5 rows x 25 columns]

# %%
# Filtrar apenas as linhas onde o Estado é "Pará"
df_para_gado_rs = df_gado_rs[df_gado_rs["State"] == "Pará"]
df_para_gado_rs.head(1)
# Out:
#    Sigla  Codigo State     1999      2000      2001      2002      2003  \
# 13    PA      15  Pará  8862649  10271409  11046992  12190597  13376606
#
#         2004      2005  ...      2011      2012      2013      2014      2015  \
# 13  17430496  18063669  ...  18262547  18605051  19163840  19904365  20261880
#
#         2016      2017      2018      2019      2020
# 13  20466797  20574246  20615756  20940237  22252351
#
# [1 rows x 25 columns]

# %% [markdown]
# ## Cálculo da Produção de Rebanho Bovino (R$) por km² (em milhões de R$)
#
# A fórmula utilizada para calcular a produção de rebanho bovino por km² em milhões de reais é:
#
# $$
# \text{Quantitativo Bovino por km² no ano X} = \left( \frac{\text{Quantitativo Bovino no ano X}}{\text{Área total (km²)}} \right)
# $$
#
# Onde:
#
# - **Produção de Rebanho Bovino (R$) no ano X**: Valor da produção de rebanho bovino em reais para um determinado ano.
# - **Área total (km²)**: Área total considerada no cálculo (**1.247.954,666 km²**).

# %%
para_km = 1247954.666
colunas_producao = df_para_gado_rs.columns[3:]
for i , linha in df_para_gado_rs.iterrows():
    if i >= 3:
        producao_gado_para_por_km2 = (linha[colunas_producao]/para_km)

# %%
# Inicializando uma lista vazia para armazenar os valores do dicionário
dados = []

# Preenchendo os dados com um for
for valor in producao_gado_para_por_km2:
    dados.append({'Produção Rebanho Bovino(R$)/km²': valor})

# Criando o DataFrame com os dados preenchidos
df_producao_gado_km = pd.DataFrame(dados)

# Exibindo o DataFrame invertido
print(df_producao_gado_km.head(22))
# Out:
#     Produção Rebanho Bovino(R$)/km²
# 0                          7.101740
# 1                          8.230595
# 2                          8.852078
# 3                          9.768461
# 4                         10.718824
# 5                         13.967251
# 6                         14.474620
# 7                         14.024290
# 8                         12.303323
# 9                         13.013852
# 10                        13.507350
# 11                        14.129791
# 12                        14.633983
# 13                        14.908435
# 14                        15.356199
# 15                        15.949590
# 16                        16.236071
# 17                        16.400273
# 18                        16.486373
# 19                        16.519635
# 20                        16.779646
# 21                        17.831057

# %%
# Concatenar os dois DataFrames por linhas (verticalmente), ignorando os índices
df_producao_gado_milho_rs_para_km = pd.concat([df_producao_milho_rs_para_km, df_producao_gado_km], axis=1)

# Exibir o DataFrame resultante
df_producao_gado_milho_rs_para_km .head(35)
# Out:
#     year  area km²    uf  Produção Milho (R$)/km²  \
# 0   1999      5111  Pará                 0.230019
# 1   2000      6671  Pará                 0.222992
# 2   2001      5237  Pará                 0.200854
# 3   2002      7510  Pará                 0.217638
# 4   2003      7145  Pará                 0.307445
# 5   2004      8870  Pará                 0.284869
# 6   2005      5899  Pará                 0.230198
# 7   2006      5659  Pará                 0.228860
# 8   2007      5526  Pará                 0.106208
# 9   2008      5607  Pará                 0.107539
# 10  2009      4281  Pará                 0.110131
# 11  2010      3770  Pará                 0.091311
# 12  2011      3008  Pará                 0.217667
# 13  2012      1741  Pará                 0.211925
# 14  2013      2346  Pará                 0.223634
# 15  2014      1887  Pará                 0.181030
# 16  2015      2153  Pará                 0.213674
# 17  2016      2992  Pará                 0.233286
# 18  2017      2433  Pará                 0.210444
# 19  2018      2744  Pará                 0.210990
# 20  2019      4172  Pará                 0.212645
# 21  2020      4899  Pará                 0.278021
#
#     Produção Rebanho Bovino(R$)/km²
# 0                          7.101740
# 1                          8.230595
# 2                          8.852078
# 3                          9.768461
# 4                         10.718824
# 5                         13.967251
# 6                         14.474620
# 7                         14.024290
# 8                         12.303323
# 9                         13.013852
# 10                        13.507350
# 11                        14.129791
# 12                        14.633983
# 13                        14.908435
# 14                        15.356199
# 15                        15.949590
# 16                        16.236071
# 17                        16.400273
# 18                        16.486373
# 19                        16.519635
# 20                        16.779646
# 21                        17.831057

# %%
with pd.ExcelWriter("Produção de Milho(R$)km + Produção Rebanho Bovino(R$)km + desmatamento.xlsx") as writer:
    df_producao_gado_milho_rs_para_km.to_excel(writer, index=False)

# %%
df_producao_gado_milho_rs_para_km = pd.read_excel("Produção de Milho(R$)km + Produção Rebanho Bovino(R$)km + desmatamento.xlsx")
df_producao_gado_milho_rs_para_km.head()
# Out:
#    year  area km²    uf  Produção Milho (R$)/km²  \
# 0  1999      5111  Pará                 0.230019
# 1  2000      6671  Pará                 0.222992
# 2  2001      5237  Pará                 0.200854
# 3  2002      7510  Pará                 0.217638
# 4  2003      7145  Pará                 0.307445
#
#    Produção Rebanho Bovino(R$)/km²
# 0                         7.101740
# 1                         8.230595
# 2                         8.852078
# 3                         9.768461
# 4                        10.718824

# %%
df_soja_rs = pd.read_excel("Producao-Soja/Produção-soja.xls")
df_soja_rs.head(20)
# Out:
#    Sigla  Codigo               Estado          1999          2000  \
# 0     AC      12                 Acre  1.358883e+02           NaN
# 1     AL      27              Alagoas           NaN           NaN
# 2     AM      13             Amazonas  8.752875e+02  8.113956e+02
# 3     AP      16                Amapá           NaN           NaN
# 4     BA      29                Bahia  6.888470e+05  9.163055e+05
# 5     CE      23                Ceará           NaN           NaN
# 6     DF      53     Distrito Federal  3.755094e+04  5.741677e+04
# 7     ES      32       Espírito Santo           NaN           NaN
# 8     GO      52                Goiás  1.882666e+06  2.355046e+06
# 9     MA      21             Maranhão  2.439664e+05  2.563868e+05
# 10    MG      31         Minas Gerais  8.045393e+05  8.740455e+05
# 11    MS      50   Mato Grosso do Sul  1.614377e+06  1.420268e+06
# 12    MT      51          Mato Grosso  3.470093e+06  4.793548e+06
# 13    PA      15                 Pará  1.887095e+03  1.636652e+03
# 14    PB      25              Paraíba           NaN           NaN
# 15    PE      26           Pernambuco           NaN           NaN
# 16    PI      22                Piauí  4.302815e+04  5.770445e+04
# 17    PR      41               Paraná  4.603671e+06  4.478770e+06
# 18    RJ      33       Rio de Janeiro           NaN           NaN
# 19    RN      24  Rio Grande do Norte           NaN           NaN
#
#             2001          2002          2003          2004          2005  ...  \
# 0            NaN           NaN           NaN           NaN  8.342878e+01  ...
# 1            NaN           NaN           NaN  4.805945e+02  9.392930e+02  ...
# 2   8.093234e+02  1.538794e+03  2.206276e+03  2.110907e+03  1.911670e+03  ...
# 3            NaN           NaN           NaN           NaN           NaN  ...
# 4   9.094542e+05  1.222699e+06  1.579248e+06  2.186123e+06  1.522282e+06  ...
# 5            NaN  3.913476e+02  1.948184e+03  1.135810e+03  9.062092e+02  ...
# 6   4.913928e+04  9.421409e+04  1.138006e+05  1.455166e+05  1.125382e+05  ...
# 7            NaN           NaN           NaN           NaN           NaN  ...
# 8   2.460145e+06  4.926949e+06  5.164282e+06  5.897889e+06  4.132481e+06  ...
# 9   2.795378e+05  3.805989e+05  6.613933e+05  6.581781e+05  6.837679e+05  ...
# 10  8.672422e+05  1.332596e+06  2.130890e+06  2.510181e+06  1.944525e+06  ...
# 11  1.823333e+06  2.494203e+06  3.831105e+06  3.197844e+06  2.323858e+06  ...
# 12  4.716570e+06  7.680936e+06  1.118494e+07  1.486692e+07  9.605948e+06  ...
# 13  1.785518e+03  8.372180e+03  3.478590e+04  8.602951e+04  1.490081e+05  ...
# 14           NaN           NaN           NaN           NaN           NaN  ...
# 15           NaN           NaN           NaN           NaN           NaN  ...
# 16  7.999369e+04  7.610572e+04  2.679435e+05  3.788275e+05  3.789033e+05  ...
# 17  5.282397e+06  7.703110e+06  1.081903e+07  1.118139e+07  6.456096e+06  ...
# 18           NaN           NaN           NaN           NaN           NaN  ...
# 19           NaN           NaN           NaN           NaN           NaN  ...
#
#             2011          2012          2013          2014          2015  \
# 0   1.818709e+02  0.000000e+00  1.026277e+02  6.838297e+02  0.000000e+00
# 1   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  5.068004e+02
# 2   2.991176e+02  4.310548e+02  3.659594e+01  0.000000e+00  0.000000e+00
# 3   0.000000e+00  0.000000e+00  9.000215e+03  2.665608e+04  1.642609e+04
# 4   2.199275e+06  2.294141e+06  1.830873e+06  2.284841e+06  3.053447e+06
# 5   0.000000e+00  3.262846e+03  0.000000e+00  0.000000e+00  0.000000e+00
# 6   1.177074e+05  1.273109e+05  1.235471e+05  1.606137e+05  1.178122e+05
# 7   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 8   4.705257e+06  5.337007e+06  5.762897e+06  6.198201e+06  5.564990e+06
# 9   9.559236e+05  1.043600e+06  1.051249e+06  1.279353e+06  1.337234e+06
# 10  1.979250e+06  2.149529e+06  2.343957e+06  2.547733e+06  2.402564e+06
# 11  3.062777e+06  2.870567e+06  3.729986e+06  4.391555e+06  4.410870e+06
# 12  1.222373e+07  1.277150e+07  1.421339e+07  1.745743e+07  1.637445e+07
# 13  2.117227e+05  3.022994e+05  3.810958e+05  4.795947e+05  6.190686e+05
# 14  0.000000e+00  0.000000e+00  0.000000e+00  7.745643e+02  0.000000e+00
# 15  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 16  7.428125e+05  7.991774e+05  6.166790e+05  1.055558e+06  1.118702e+06
# 17  9.979284e+06  7.594003e+06  1.163731e+07  1.156258e+07  1.131303e+07
# 18  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 19  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#             2016          2017          2018          2019          2020
# 0   1.237049e+02  1.695014e+02  1.018365e+03  3.574049e+03  7.643921e+03
# 1   1.016283e+03  8.028367e+02  1.600456e+03  7.966742e+03  3.860220e+03
# 2   0.000000e+00  0.000000e+00  0.000000e+00  5.056822e+03  5.277129e+03
# 3   2.358767e+04  2.967253e+04  3.076587e+04  2.696073e+04  2.346581e+04
# 4   2.215305e+06  3.259237e+06  4.159184e+06  3.329493e+06  5.432937e+06
# 5   0.000000e+00  0.000000e+00  1.300041e+02  0.000000e+00  1.211101e+03
# 6   1.774563e+05  1.527036e+05  1.912067e+05  1.567913e+05  2.187454e+05
# 7   0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 8   6.824954e+06  7.126800e+06  7.142821e+06  7.036025e+06  8.700218e+06
# 9   8.341466e+05  1.420984e+06  1.846384e+06  1.723906e+06  2.746498e+06
# 10  3.392453e+06  3.499017e+06  3.518115e+06  3.373098e+06  4.472901e+06
# 11  4.680107e+06  4.899721e+06  6.368336e+06  5.241584e+06  7.377139e+06
# 12  1.743740e+07  1.700708e+07  1.755438e+07  1.840935e+07  2.293933e+07
# 13  9.757341e+05  9.181129e+05  9.855691e+05  1.079400e+06  1.428549e+06
# 14  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 15  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 16  4.716246e+05  1.345785e+06  1.664615e+06  1.428647e+06  1.832747e+06
# 17  1.208512e+07  1.208412e+07  1.263921e+07  1.066616e+07  1.631502e+07
# 18  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 19  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
# [20 rows x 25 columns]

# %%
# Filtrar apenas as linhas onde o Estado é "Pará"
df_para_soja_rs = df_soja_rs[df_soja_rs["Estado"] == "Pará"]
df_para_soja_rs.head(1)
# Out:
#    Sigla  Codigo Estado         1999        2000        2001         2002  \
# 13    PA      15   Pará  1887.095073  1636.65199  1785.51757  8372.179683
#
#             2003          2004          2005  ...           2011  \
# 13  34785.900507  86029.511938  149008.11995  ...  211722.655642
#
#              2012           2013          2014           2015           2016  \
# 13  302299.449688  381095.815443  479594.74183  619068.629781  975734.141327
#
#              2017          2018          2019          2020
# 13  918112.941686  985569.05857  1.079400e+06  1.428549e+06
#
# [1 rows x 25 columns]

# %% [markdown]
# ## Cálculo da Produção de Soja (R$) por km² (em milhões de R$)
#
# A fórmula utilizada para calcular a produção de soja por km² em milhões de reais é:
#
# $$
# \text{Produção de Soja(R\$) por km² no ano X} = \left( \frac{\text{Produção de Soja (R\$) no ano X}}{\text{Área total (km²)}} \right)
# $$
#
# Onde:
#
# - **Produção de Soja (R$) no ano X**: Valor da produção de soja em reais para um determinado ano.
# - **Área total (km²)**: Área total considerada no cálculo (**1.247.954,666 km²**).

# %%
para_km = 1247954.666

colunas_producao = df_para_soja_rs.columns[3:]
for i , linha in df_para_soja_rs.iterrows():
    if i >= 3:
        producao_soja_para_por_km2 = (linha[colunas_producao]/para_km)

# %%
# Inicializando uma lista vazia para armazenar os valores do dicionário
dados = []

# Preenchendo os dados com um for
for valor in producao_soja_para_por_km2:
    dados.append({'Produção Soja(R$)/km²': valor})

# Criando o DataFrame com os dados preenchidos
df_producao_soja_km = pd.DataFrame(dados)

# Exibindo o DataFrame invertido
print(df_producao_soja_km.head(22))
# Out:
#     Produção Soja(R$)/km²
# 0                0.001512
# 1                0.001311
# 2                0.001431
# 3                0.006709
# 4                0.027874
# 5                0.068936
# 6                0.119402
# 7                0.085213
# 8                0.033051
# 9                0.061339
# 10               0.061561
# 11               0.054750
# 12               0.169656
# 13               0.242236
# 14               0.305376
# 15               0.384305
# 16               0.496067
# 17               0.781867
# 18               0.735694
# 19               0.789747
# 20               0.864935
# 21               1.144712

# %%
df_producao_soja_km.head()
# Out:
#    Produção Soja(R$)/km²
# 0               0.001512
# 1               0.001311
# 2               0.001431
# 3               0.006709
# 4               0.027874

# %%
df_producao_gado_milho_rs_para_km = pd.read_excel("Produção de Milho(R$)km + Produção Rebanho Bovino(R$)km + desmatamento.xlsx")
df_producao_gado_milho_rs_para_km.head()
# Out:
#    year  area km²    uf  Produção Milho (R$)/km²  \
# 0  1999      5111  Pará                 0.230019
# 1  2000      6671  Pará                 0.222992
# 2  2001      5237  Pará                 0.200854
# 3  2002      7510  Pará                 0.217638
# 4  2003      7145  Pará                 0.307445
#
#    Produção Rebanho Bovino(R$)/km²
# 0                         7.101740
# 1                         8.230595
# 2                         8.852078
# 3                         9.768461
# 4                        10.718824

# %%
# Concatenar os dois DataFrames por linhas (verticalmente), ignorando os índices
df_producao_gado_milho_soja_rs_para_km = pd.concat([df_producao_gado_milho_rs_para_km , df_producao_soja_km], axis=1)

# Exibir o DataFrame resultante
df_producao_gado_milho_soja_rs_para_km.head(35)
# Out:
#     year  area km²    uf  Produção Milho (R$)/km²  \
# 0   1999      5111  Pará                 0.230019
# 1   2000      6671  Pará                 0.222992
# 2   2001      5237  Pará                 0.200854
# 3   2002      7510  Pará                 0.217638
# 4   2003      7145  Pará                 0.307445
# 5   2004      8870  Pará                 0.284869
# 6   2005      5899  Pará                 0.230198
# 7   2006      5659  Pará                 0.228860
# 8   2007      5526  Pará                 0.106208
# 9   2008      5607  Pará                 0.107539
# 10  2009      4281  Pará                 0.110131
# 11  2010      3770  Pará                 0.091311
# 12  2011      3008  Pará                 0.217667
# 13  2012      1741  Pará                 0.211925
# 14  2013      2346  Pará                 0.223634
# 15  2014      1887  Pará                 0.181030
# 16  2015      2153  Pará                 0.213674
# 17  2016      2992  Pará                 0.233286
# 18  2017      2433  Pará                 0.210444
# 19  2018      2744  Pará                 0.210990
# 20  2019      4172  Pará                 0.212645
# 21  2020      4899  Pará                 0.278021
#
#     Produção Rebanho Bovino(R$)/km²  Produção Soja(R$)/km²
# 0                          7.101740               0.001512
# 1                          8.230595               0.001311
# 2                          8.852078               0.001431
# 3                          9.768461               0.006709
# 4                         10.718824               0.027874
# 5                         13.967251               0.068936
# 6                         14.474620               0.119402
# 7                         14.024290               0.085213
# 8                         12.303323               0.033051
# 9                         13.013852               0.061339
# 10                        13.507350               0.061561
# 11                        14.129791               0.054750
# 12                        14.633983               0.169656
# 13                        14.908435               0.242236
# 14                        15.356199               0.305376
# 15                        15.949590               0.384305
# 16                        16.236071               0.496067
# 17                        16.400273               0.781867
# 18                        16.486373               0.735694
# 19                        16.519635               0.789747
# 20                        16.779646               0.864935
# 21                        17.831057               1.144712

# %%
with pd.ExcelWriter("Produção de Milho(R$)km + Produção Rebanho Bovino(R$)km + Produção de Soja(R$) + desmatamento.xlsx") as writer:
    df_producao_gado_milho_soja_rs_para_km.to_excel(writer, index=False)

# %%
df_producao_gado_milho_soja_rs_para_km = pd.read_excel("Produção de Milho(R$)km + Produção Rebanho Bovino(R$)km + Produção de Soja(R$) + desmatamento.xlsx")
df_producao_gado_milho_soja_rs_para_km.head()
# Out:
#    year  area km²    uf  Produção Milho (R$)/km²  \
# 0  1999      5111  Pará                 0.229062
# 1  2000      6671  Pará                 0.222065
# 2  2001      5237  Pará                 0.200019
# 3  2002      7510  Pará                 0.216734
# 4  2003      7145  Pará                 0.306167
#
#    Produção Rebanho Bovino(R$)/km²  Produção Soja(R$)/km²
# 0                         7.072215               0.001506
# 1                         8.196377               0.001306
# 2                         8.815277               0.001425
# 3                         9.727851               0.006681
# 4                        10.674262               0.027758

# %% [markdown]
# # Levantamento de Proporção Estatísca

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# ## Desmatamento

# %%
df_desmatamento = pd.read_csv("PRODES(DESMATAMENTO)/terrabrasilis_legal_amazon_02_02_2025_taxas_de_desmatamento_estadual_por_ano.csv", delimiter=";", engine="python")

# %%
df_desmatamento.head(100)
# Out:
#     year  area km²           uf
# 0   2024     23,00    Tocantins
# 1   2024    436,00      Roraima
# 2   2024    325,00     Rondônia
# 3   2024  2.362,00         Pará
# 4   2024  1.264,00  Mato Grosso
# ..   ...       ...          ...
# 95  2014    257,00     Maranhão
# 96  2014     31,00        Amapá
# 97  2014    500,00     Amazonas
# 98  2014    309,00         Acre
# 99  2013     74,00    Tocantins
#
# [100 rows x 3 columns]

# %%
df_desmatamento['uf']
# Out:
# 0        Tocantins
# 1          Roraima
# 2         Rondônia
# 3             Pará
# 4      Mato Grosso
#           ...
# 328    Mato Grosso
# 329       Maranhão
# 330          Amapá
# 331       Amazonas
# 332           Acre
# Name: uf, Length: 333, dtype: object

# %%
df_desmatamento['uf'].unique()
# Out:
# array(['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
#        'Maranhão', 'Amapá', 'Amazonas', 'Acre'], dtype=object)

# %%
#Substituir vírgula por ponto na coluna "area km²" e converter para float
df_desmatamento["area km²"] = df_desmatamento["area km²"].str.replace(".", "", regex=False)  # Remove o ponto separador de milhar
df_desmatamento["area km²"] = df_desmatamento["area km²"].str.replace(",", ".", regex=False).astype(float)

# %%
df_desmatamento.dtypes
# Out:
# year          int64
# area km²    float64
# uf           object
# dtype: object

# %%
df_desmatamento["area km²"].head()
# Out:
# 0      23.0
# 1     436.0
# 2     325.0
# 3    2362.0
# 4    1264.0
# Name: area km², dtype: float64

# %%
menor_ano = df_desmatamento["year"].min()
maior_ano = df_desmatamento["year"].max()

print(f"Menor ano: {menor_ano}")
print(f"Maior ano: {maior_ano}")
# Out:
# Menor ano: 1988
# Maior ano: 2024

# %%
def acumulador_area_desmatada():
    # Filtra os dados dentro do intervalo desejado
    df_filtrado = df_desmatamento[(df_desmatamento["year"] >= 1999) & (df_desmatamento["year"] <= 2020)]
    
    # Soma a área total desmatada no período
    total_desmatado = df_filtrado["area km²"].sum()
    
    return total_desmatado

# Chamando a função e imprimindo o resultado
print(f"Total de área desmatada (1999-2020): {acumulador_area_desmatada()} km²")
# Out:
# Total de área desmatada (1999-2020): 272249.0 km²

# %%
def acumulador_para_desmatado():
    # Certifique-se de que a coluna "year" está no formato numérico
    df_desmatamento["year"] = df_desmatamento["year"].astype(int)

    # Filtra os dados para o intervalo de 1999 a 2020 e apenas para o estado do Pará
    df_filtrado = df_desmatamento[
        (df_desmatamento["year"] >= 1999) & 
        (df_desmatamento["year"] <= 2020) & 
        (df_desmatamento["uf"] == "Pará")  # Filtra apenas o estado do Pará
    ]

    # Soma a área total desmatada no Pará no período
    total_desmatado_para = df_filtrado["area km²"].sum()

    return total_desmatado_para

# Chamando a função e imprimindo o resultado
print(f"Total de área desmatada no Pará (1999-2020): {acumulador_para_desmatado()} km²")
# Out:
# Total de área desmatada no Pará (1999-2020): 99661.0 km²

# %%
# Obtendo os valores das funções
total_legal = acumulador_area_desmatada()
total_para = acumulador_para_desmatado()

# Criando o histograma
plt.figure(figsize=(8, 5))
plt.bar(["Amazônia Legal", "Pará"], [total_legal, total_para], color=["blue", "green"])

# Adicionando rótulos e título
plt.xlabel("Território")
plt.ylabel("Área Desmatada (km²)")
plt.title("Comparação da Área Desmatada (1999-2020)")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Exibir os valores exatos em cada barra
for i, valor in enumerate([total_legal, total_para]):
    plt.text(i, valor, f"{valor:.2f}", ha="center", fontsize=12, fontweight="bold")

plt.show()

# %%
total_brasil = acumulador_area_desmatada()  # Total de área desmatada no Brasil
total_para = acumulador_para_desmatado()  # Total de área desmatada no Pará

#https://terrabrasilis.dpi.inpe.br/app/dashboard/deforestation/biomes/legal_amazon/rates : Taxas de desmatamento - Amazônia Legal - Estados

# Calculando a porcentagem
porcentagem_para = (total_para / total_brasil) * 100

print(f"A área desmatada no Pará representa {porcentagem_para:.2f}% do total de área desmatada no Brasil.")
# Out:
# A área desmatada no Pará representa 36.61% do total de área desmatada no Brasil.

# %% [markdown]
# ## Milho

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
df_milho = pd.read_excel("./Producao-Milhos/Produção - milho(R$).xls")

# %%
df_milho.head()
# Out:
#   Sigla  Codigo    Estado           1999           2000           2001  \
# 0    AC      12      Acre   18904.944259   24988.623815   20954.800824
# 1    AL      27   Alagoas   10014.796780   17410.158922   13512.363104
# 2    AM      13  Amazonas   12572.435225   12887.722412    9962.186814
# 3    AP      16     Amapá     663.587846     679.718502    1040.856621
# 4    BA      29     Bahia  375105.438329  501726.823716  399834.954285
#
#             2002           2003           2004           2005  ...  \
# 0   29299.779272   35786.634134   26947.290855   27006.472107  ...
# 1   36330.738430    7552.957958   16491.655465   17100.023457  ...
# 2   10032.557501   12040.440695   11903.600267   18459.337233  ...
# 3    1229.135524     602.771336     647.489097     903.332329  ...
# 4  638859.811464  708056.506271  711164.008933  583660.566800  ...
#
#             2011           2012           2013           2014           2015  \
# 0   38268.591893   47024.320828   52944.780696   44083.775580   39699.818002
# 1   15097.131217     776.582942    3381.146776    4173.057538    7536.855013
# 2   20775.750071   21562.150384   17517.522557   16321.914633   12750.932234
# 3    1487.279300    1152.900667     791.586128     750.958560     680.991540
# 4  745510.058300  719756.399612  701582.387122  831413.663386  793235.816620
#
#             2016           2017           2018           2019          2020
# 0   36829.169319   37864.276573   33140.497163   30894.373353  3.755522e+04
# 1    8125.826024   11220.132765    9889.093433   17008.340016  3.381848e+04
# 2    6198.567107    5769.165124    3934.672753    3177.369852  3.391611e+03
# 3     590.611603     594.784525     426.905259     459.047068  5.124092e+02
# 4  702204.208474  526824.273705  672710.163159  586494.715801  1.130002e+06
#
# [5 rows x 25 columns]

# %%
df_colunas_milhos = df_milho.loc[:, '1999':'2020'].head()

# %%
df_colunas_milhos.columns
# Out:
# Index(['1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
def acumulador_milho_amazonia():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # Soma a produção de milho de 1999 a 2020
    df_milho_estados = df_milho_filtrado.loc[:, '1999':'2020']
    
    return df_milho_estados.sum()

# %%
def acumulador_milho_para():
    para = ['Pará']
     # Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(para)]
    
    # Soma a produção de milho de 1999 a 2020
    df_milho_estados = df_milho_filtrado.loc[:, '1999':'2020']
    
    return df_milho_estados.sum()

# %%
# Calculando os totais
total_legal_milho = acumulador_milho_amazonia().sum()  # Soma total da Amazônia Legal
total_para_milho = acumulador_milho_para().sum()       # Soma total do Pará


# Dados para o histograma
territorios = ["Amazônia Legal", "Pará"]
producao_milho = [total_legal_milho, total_para_milho]

# Criando o histograma
plt.figure(figsize=(8, 5))  # Define o tamanho da figura
bars = plt.bar(territorios, producao_milho, color=["blue", "green"])  # Cria as barras

# Adicionando rótulos e título
plt.xlabel("Território")
plt.ylabel("Produção de Milho (R$)")
plt.title("Comparação da Produção de Milho (R$) (1999-2020)")
plt.grid(axis="y", linestyle="--", alpha=0.7)  # Adiciona uma grade horizontal

# Exibir os valores exatos em cada barra
for bar, valor in zip(bars, producao_milho):
    height = bar.get_height()  # Altura da barra
    # Ajusta a posição do texto para evitar sobreposição com o título
    text_y = height + (0.02 * max(producao_milho))  # Posição Y (baseada no valor máximo)
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # Posição X (centro da barra)
        text_y,                             # Posição Y (ajustada para evitar sobreposição)
        f"{valor:.2f}",                     # Valor formatado
        ha="center",                        # Alinhamento horizontal
        fontsize=12,                        # Tamanho da fonte
        fontweight="bold"                   # Peso da fonte
    )

# Ajusta os limites do eixo Y para garantir que o texto caiba

plt.ylim(0, max(producao_milho) * 1.15)  # Aumenta o limite superior em 15%
plt.show()

# %%
# Calculando a proporção do Pará em relação à Amazônia Legal
proporcao_para_milho = (total_para_milho / total_legal_milho) * 100

# %%
# Exibindo o resultado
print(f"A produção de milho do Pará representa {proporcao_para_milho:.2f}% do total da Amazônia Legal.")
# Out:
# A produção de milho do Pará representa 7.24% do total da Amazônia Legal.

# %% [markdown]
# ## Soja

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
df_soja = pd.read_excel("./Producao-Soja/Produção-Soja.xls")

# %%
df_soja.head()
# Out:
#   Sigla  Codigo    Estado           1999           2000           2001  \
# 0    AC      12      Acre     135.888296            NaN            NaN
# 1    AL      27   Alagoas            NaN            NaN            NaN
# 2    AM      13  Amazonas     875.287508     811.395620     809.323384
# 3    AP      16     Amapá            NaN            NaN            NaN
# 4    BA      29     Bahia  688846.998305  916305.480288  909454.208488
#
#            2002          2003          2004          2005  ...          2011  \
# 0           NaN           NaN           NaN  8.342878e+01  ...  1.818709e+02
# 1           NaN           NaN  4.805945e+02  9.392930e+02  ...  0.000000e+00
# 2  1.538794e+03  2.206276e+03  2.110907e+03  1.911670e+03  ...  2.991176e+02
# 3           NaN           NaN           NaN           NaN  ...  0.000000e+00
# 4  1.222699e+06  1.579248e+06  2.186123e+06  1.522282e+06  ...  2.199275e+06
#
#            2012          2013          2014          2015          2016  \
# 0  0.000000e+00  1.026277e+02  6.838297e+02  0.000000e+00  1.237049e+02
# 1  0.000000e+00  0.000000e+00  0.000000e+00  5.068004e+02  1.016283e+03
# 2  4.310548e+02  3.659594e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 3  0.000000e+00  9.000215e+03  2.665608e+04  1.642609e+04  2.358767e+04
# 4  2.294141e+06  1.830873e+06  2.284841e+06  3.053447e+06  2.215305e+06
#
#            2017          2018          2019          2020
# 0  1.695014e+02  1.018365e+03  3.574049e+03  7.643921e+03
# 1  8.028367e+02  1.600456e+03  7.966742e+03  3.860220e+03
# 2  0.000000e+00  0.000000e+00  5.056822e+03  5.277129e+03
# 3  2.967253e+04  3.076587e+04  2.696073e+04  2.346581e+04
# 4  3.259237e+06  4.159184e+06  3.329493e+06  5.432937e+06
#
# [5 rows x 25 columns]

# %%
df_colunas_soja = df_soja.loc[:, '1999':'2020'].head()

# %%
df_colunas_soja.columns
# Out:
# Index(['1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
df_soja.dtypes
# Out:
# Sigla      object
# Codigo      int64
# Estado     object
# 1999      float64
# 2000      float64
# 2001      float64
# 2002      float64
# 2003      float64
# 2004      float64
# 2005      float64
# 2006      float64
# 2007      float64
# 2008      float64
# 2009      float64
# 2010      float64
# 2011      float64
# 2012      float64
# 2013      float64
# 2014      float64
# 2015      float64
# 2016      float64
# 2017      float64
# 2018      float64
# 2019      float64
# 2020      float64
# dtype: object

# %%
def acumulador_soja_amazonia():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # Filtra apenas os estados da Amazônia
    df_soja_filtrado = df_soja[df_soja['Estado'].isin(estados_amazonia)]
    
    # Soma a produção de milho de 1999 a 2020
    df_soja_estados = df_soja_filtrado.loc[:, '1999':'2020']
    
    return df_soja_estados.sum()

# %%
def acumulador_soja_para():
    para = ['Pará']
     # Filtra apenas os estados da Amazônia
    df_soja_filtrado = df_soja[df_soja['Estado'].isin(para)]
    
    # Soma a produção de soja de 1999 a 2020
    df_soja_estados = df_soja_filtrado.loc[:, '1999':'2020']
    
    return df_soja_estados.sum()

# %%
# Calculando os totais
total_legal_soja = acumulador_soja_amazonia().sum()  # Soma total da Amazônia Legal
total_para_soja = acumulador_soja_para().sum()       # Soma total do Pará


# Dados para o histograma
territorios = ["Amazônia Legal", "Pará"]
producao_soja = [total_legal_soja, total_para_soja]

# Criando o histograma
plt.figure(figsize=(8, 5))  # Define o tamanho da figura
bars = plt.bar(territorios, producao_soja, color=["blue", "green"])  # Cria as barras

# Adicionando rótulos e título
plt.xlabel("Território")
plt.ylabel("Produção de soja (R$)")
plt.title("Comparação da Produção de soja (R$) (1999-2020)")
plt.grid(axis="y", linestyle="--", alpha=0.7)  # Adiciona uma grade horizontal

# Exibir os valores exatos em cada barra
for bar, valor in zip(bars, producao_soja):
    height = bar.get_height()  # Altura da barra
    # Ajusta a posição do texto para evitar sobreposição com o título
    text_y = height + (0.02 * max(producao_soja))  # Posição Y (baseada no valor máximo)
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # Posição X (centro da barra)
        text_y,                             # Posição Y (ajustada para evitar sobreposição)
        f"{valor:.2f}",                     # Valor formatado
        ha="center",                        # Alinhamento horizontal
        fontsize=12,                        # Tamanho da fonte
        fontweight="bold"                   # Peso da fonte
    )

# Ajusta os limites do eixo Y para garantir que o texto caiba

plt.ylim(0, max(producao_soja) * 1.15)  # Aumenta o limite superior em 15%
plt.show()

# %%
# Calculando a proporção do Pará em relação à Amazônia Legal
proporcao_para_soja = (total_para_soja / total_legal_soja) * 100

# %%
# Exibindo o resultado
print(f"A produção de milho do Pará representa {proporcao_para_soja:.2f}% do total da Amazônia Legal.")
# Out:
# A produção de milho do Pará representa 2.70% do total da Amazônia Legal.

# %% [markdown]
# ## Efetivo Bovino

# %%
df_bovino = pd.read_excel("./Rebanho-bovino/Efetivo - bovinos - quantidade.xls")
df_bovino.head()
# Out:
#   Sigla  Codigo    Estado     1999     2000     2001     2002      2003  \
# 0    AC      12      Acre   929999  1033311  1672598  1817467   1874804
# 1    AL      27   Alagoas   815472   778750   843240   816067    825121
# 2    AM      13  Amazonas   826025   843254   863736   894856   1121009
# 3    AP      16     Amapá    76734    82822    87197    83901     81674
# 4    BA      29     Bahia  9170680  9556752  9855828  9856290  10146529
#
#        2004      2005  ...      2011      2012      2013      2014      2015  \
# 0   2062690   2313185  ...   2549497   2634467   2697489   2799673   2916207
# 1    893922    985422  ...   1268304   1221266   1251723   1253121   1255696
# 2   1156723   1197171  ...   1439597   1445739   1470537   1405208   1293325
# 3     82243     96599  ...    127499    142825    154967    167529     89682
# 4  10466163  10463098  ...  10667903  10250975  10828409  10824134  10758372
#
#        2016      2017     2018      2019     2020
# 0   2998969   2895028  3303633   3509682  3802112
# 1   1189985   1208404  1247619   1233394  1290414
# 2   1315821   1343574  1376210   1455842  1437809
# 3     76379     66921    55422     54296    54684
# 4  10363291  10037814  9923931  10214863  9748632
#
# [5 rows x 25 columns]

# %%
df_colunas_bovino = df_bovino.loc[:, '1999':'2020'].head()

# %%
def acumulador_bovino_amazonia():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # Filtra apenas os estados da Amazônia
    df_bovino_filtrado = df_bovino[df_bovino['Estado'].isin(estados_amazonia)]
    
    # Soma a produção de milho de 1999 a 2020
    df_bovino_estados = df_bovino_filtrado.loc[:, '1999':'2020']
    
    return df_bovino_estados.sum()

# %%
def acumulador_bovino_para():
    para = ['Pará']
     # Filtra apenas os estados da Amazônia
    df_bovino_filtrado = df_bovino[df_bovino['Estado'].isin(para)]
    
    # Soma a produção de bovino de 1999 a 2020
    df_bovino_estados = df_bovino_filtrado.loc[:, '1999':'2020']
    
    return df_bovino_estados.sum()

# %%
# Calculando os totais
total_legal_bovino = acumulador_bovino_amazonia().sum()  # Soma total da Amazônia Legal
total_para_bovino = acumulador_bovino_para().sum()       # Soma total do Pará


# Dados para o histograma
territorios = ["Amazônia Legal", "Pará"]
producao_bovino = [total_legal_bovino, total_para_bovino]

# Criando o histograma
plt.figure(figsize=(8, 5))  # Define o tamanho da figura
bars = plt.bar(territorios, producao_bovino, color=["blue", "green"])  # Cria as barras

# Adicionando rótulos e título
plt.xlabel("Território")
plt.ylabel("Quantitativo Bovino")
plt.title("Comparação Quantitativo Bovino (1999-2020)")
plt.grid(axis="y", linestyle="--", alpha=0.7)  # Adiciona uma grade horizontal

# Exibir os valores exatos em cada barra
for bar, valor in zip(bars, producao_bovino):
    height = bar.get_height()  # Altura da barra
    # Ajusta a posição do texto para evitar sobreposição com o título
    text_y = height + (0.02 * max(producao_bovino))  # Posição Y (baseada no valor máximo)
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # Posição X (centro da barra)
        text_y,                             # Posição Y (ajustada para evitar sobreposição)
        f"{valor:.2f}",                     # Valor formatado
        ha="center",                        # Alinhamento horizontal
        fontsize=12,                        # Tamanho da fonte
        fontweight="bold"                   # Peso da fonte
    )

# Ajusta os limites do eixo Y para garantir que o texto caiba

plt.ylim(0, max(producao_bovino) * 1.15)  # Aumenta o limite superior em 15%
plt.show()

# %%
# Calculando a proporção do Pará em relação à Amazônia Legal
proporcao_para_bovino = (total_para_bovino / total_legal_bovino) * 100

# %%
# Exibindo o resultado
print(f"A produção de milho do Pará representa {proporcao_para_bovino:.2f}% do total da Amazônia Legal.")
# Out:
# A produção de milho do Pará representa 23.09% do total da Amazônia Legal.

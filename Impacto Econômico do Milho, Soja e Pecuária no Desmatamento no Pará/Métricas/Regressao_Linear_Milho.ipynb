# %% [markdown]
# # Regressão Linear:
#
# ## Aplicado com a densidade: Produção Milho (R$)/km²

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df_dados_geral= pd.read_excel("Produção de Milho(R$)km + Produção Rebanho Bovino(R$)km + Produção de Soja(R$) + desmatamento.xlsx")
df_dados_geral.head()
# Out:
#    year  area km²    uf  Produção Milho (R$)/km²  \
# 0  1999      5111  Pará                 0.230019
# 1  2000      6671  Pará                 0.222992
# 2  2001      5237  Pará                 0.200854
# 3  2002      7510  Pará                 0.217638
# 4  2003      7145  Pará                 0.307445
#
#    Produção Rebanho Bovino(R$)/km²  Produção Soja(R$)/km²
# 0                         7.101740               0.001512
# 1                         8.230595               0.001311
# 2                         8.852078               0.001431
# 3                         9.768461               0.006709
# 4                        10.718824               0.027874

# %%
df_dados_geral = df_dados_geral.rename(columns={"Produção Rebanho Bovino(R$)/km²": "Quantitativo Bovino/km²"})

# %%
df_dados_geral.head()
# Out:
#    year  area km²    uf  Produção Milho (R$)/km²  Quantitativo Bovino/km²  \
# 0  1999      5111  Pará                 0.230019                 7.101740
# 1  2000      6671  Pará                 0.222992                 8.230595
# 2  2001      5237  Pará                 0.200854                 8.852078
# 3  2002      7510  Pará                 0.217638                 9.768461
# 4  2003      7145  Pará                 0.307445                10.718824
#
#    Produção Soja(R$)/km²
# 0               0.001512
# 1               0.001311
# 2               0.001431
# 3               0.006709
# 4               0.027874

# %%
X = df_dados_geral[["area km²"]]  # Variável independente (área desmatada)
y = df_dados_geral[["Produção Milho (R$)/km²"]]

# %%
print(f'->{X.shape}')
print(f'->{y.shape}')
# Out:
# ->(22, 1)
# ->(22, 1)

# %%
modelo = LinearRegression()  # Cria o modelo
modelo.fit(X, y)  # Treina o modelo
# Out:
# LinearRegression()

# %%
y_pred = modelo.predict(X)  # Previsões para os dados de entrada

# %%
plt.scatter(X, y, color='blue', label='Dados observados')  # Dados reais
plt.plot(X, y_pred, color='red', label='Regressão linear')  # Linha de regressão
plt.xlabel("Área Desmatada (km²)")
plt.ylabel("Produção Milho (R$)/km²")
plt.title("Regressão Linear: Área Desmatada vs. Produção Milho (R$)/km²")
plt.legend()
plt.show()

# %%
r2 = modelo.score(X, y)
print(f"Coeficiente de determinação (R²): {r2:.2f}")
# Out:
# Coeficiente de determinação (R²): 0.06

# %%
r2_percentual = r2 * 100  # Convertendo R² para porcentagem
print(f"Coeficiente de determinação (R²): {r2_percentual:.2f}%")
# Out:
# Coeficiente de determinação (R²): 6.19%

# %% [markdown]
# # Regressão Linear:
#
# ## Aplicado com a densidade: Produção de Soja(R$)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df_dados_geral= pd.read_excel("Produção de Milho(R$)km + Produção Rebanho Bovino(R$)km + Produção de Soja(R$) + desmatamento.xlsx")
df_dados_geral.head(0)
# Out:
# Empty DataFrame
# Columns: [year, area km², uf, Produção Milho (R$)/km², Produção Rebanho Bovino(R$)/km², Produção Soja(R$)/km²]
# Index: []

# %%
df_dados_geral = pd.read_excel("Produção de Milho(R$)km + Produção Rebanho Bovino(R$)km + Produção de Soja(R$) + desmatamento.xlsx")
df_dados_geral = df_dados_geral.drop(columns=["uf"], errors="ignore")
df_dados_geral = df_dados_geral.rename(columns={"Produção Rebanho Bovino(R$)/km²": "Quantitativo Bovino/km²"})
df_dados_geral = df_dados_geral.rename(columns={"area km²": "Area Desmatada km²"})

# Exibir o cabeçalho do DataFrame
df_dados_geral.head()
# Out:
#    year  Area Desmatada km²  Produção Milho (R$)/km²  Quantitativo Bovino/km²  \
# 0  1999                5111                 0.230019                 7.101740
# 1  2000                6671                 0.222992                 8.230595
# 2  2001                5237                 0.200854                 8.852078
# 3  2002                7510                 0.217638                 9.768461
# 4  2003                7145                 0.307445                10.718824
#
#    Produção Soja(R$)/km²
# 0               0.001512
# 1               0.001311
# 2               0.001431
# 3               0.006709
# 4               0.027874

# %%
df_dados_geral = df_dados_geral.rename(columns={"year": "Ano"})

# Exibir o cabeçalho do DataFrame
df_dados_geral.head()
# Out:
#     Ano  Area Desmatada km²  Produção Milho (R$)/km²  Quantitativo Bovino  \
# 0  1999                5111                 0.230019             7.101740
# 1  2000                6671                 0.222992             8.230595
# 2  2001                5237                 0.200854             8.852078
# 3  2002                7510                 0.217638             9.768461
# 4  2003                7145                 0.307445            10.718824
#
#    Produção Soja(R$)/km²
# 0               0.001512
# 1               0.001311
# 2               0.001431
# 3               0.006709
# 4               0.027874

# %%
df_dados_geral.head()
# Out:
#     Ano  Area Desmatada km²  Produção Milho (R$)/km²  Quantitativo Bovino  \
# 0  1999                5111                 0.230019             7.101740
# 1  2000                6671                 0.222992             8.230595
# 2  2001                5237                 0.200854             8.852078
# 3  2002                7510                 0.217638             9.768461
# 4  2003                7145                 0.307445            10.718824
#
#    Produção Soja(R$)/km²
# 0               0.001512
# 1               0.001311
# 2               0.001431
# 3               0.006709
# 4               0.027874

# %%
df_dados_geral.dtypes
# Out:
# Ano                          int64
# Area Desmatada km²           int64
# Produção Milho (R$)/km²    float64
# Quantitativo Bovino        float64
# Produção Soja(R$)/km²      float64
# dtype: object

# %%
X = df_dados_geral[["Area Desmatada km²"]]
y = df_dados_geral[["Produção Soja(R$)/km²"]]

# %%
print(X.shape)
print(y.shape)
# Out:
# (22, 1)
# (22, 1)

# %%
modelo = LinearRegression()  # Cria o modelo
modelo.fit(X, y)  # Treina o modelo
# Out:
# LinearRegression()

# %%
# Verificando o shape de X e y
print(f"Shape de X: {X.shape}")
print(f"Shape de y: {y.shape}")
# Out:
# Shape de X: (22, 1)
# Shape de y: (22, 1)

# %%
y_pred = modelo.predict(X)  # Previsões para os dados de entrada

# %%
plt.scatter(X, y, color='blue', label='Dados observados')  # Dados reais
plt.plot(X, y_pred, color='red', label='Regressão linear')  # Linha de regressão
plt.xlabel("Área Desmatada (km²)")
plt.ylabel("Produção Soja(R$)/km²)")
plt.title("Regressão Linear: Área Desmatada vs. Produção Soja(R$)/km²")
plt.legend()
plt.show()

# %%
r2 = modelo.score(X, y)
print(f"Coeficiente de determinação (R²): {r2:.2f}")
# Out:
# Coeficiente de determinação (R²): 0.24

# %%
r2_percentual = r2 * 100  # Convertendo R² para porcentagem
print(f"Coeficiente de determinação (R²): {r2_percentual:.2f}%")
# Out:
# Coeficiente de determinação (R²): 23.78%

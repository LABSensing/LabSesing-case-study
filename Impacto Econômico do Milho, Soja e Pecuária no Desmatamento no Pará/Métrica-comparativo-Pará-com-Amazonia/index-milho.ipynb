# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
df_milho = pd.read_excel("../Producao-Milhos/Produção - milho(R$).xls")

# %%
df_milho.head(100)
# Out:
#    Sigla  Codigo               Estado          1999          2000  \
# 0     AC      12                 Acre  1.890494e+04  2.498862e+04
# 1     AL      27              Alagoas  1.001480e+04  1.741016e+04
# 2     AM      13             Amazonas  1.257244e+04  1.288772e+04
# 3     AP      16                Amapá  6.635878e+02  6.797185e+02
# 4     BA      29                Bahia  3.751054e+05  5.017268e+05
# 5     CE      23                Ceará  2.103538e+05  3.082783e+05
# 6     DF      53     Distrito Federal  3.791741e+04  5.580912e+04
# 7     ES      32       Espírito Santo  5.781818e+04  6.007141e+04
# 8     GO      52                Goiás  9.709671e+05  1.450633e+06
# 9     MA      21             Maranhão  9.656050e+04  1.317080e+05
# 10    MG      31         Minas Gerais  1.468290e+06  1.907485e+06
# 11    MS      50   Mato Grosso do Sul  5.790661e+05  4.158691e+05
# 12    MT      51          Mato Grosso  2.874550e+05  5.262078e+05
# ...

# %%
df_colunas_milho = df_milho.loc[:, '1999':'2020'].head(10)

# %%
df_colunas_milho.columns
# Out:
# Index(['1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
df_milho.dtypes
# Out:
# Sigla      object
# Codigo      int64
# Estado     object
# 1999      float64
# 2000      float64
# 2001      float64
# 2002      float64
# 2003      float64
# 2004      float64
# 2005      float64
# 2006      float64
# 2007      float64
# 2008      float64
# 2009      float64
# 2010      float64
# 2011      float64
# 2012      float64
# 2013      float64
# 2014      float64
# 2015      float64
# 2016      float64
# 2017      float64
# 2018      float64
# 2019      float64
# 2020      float64
# dtype: object

# %%
df_milho["Pará"].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Matheus\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pará'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df_milho["Pará"].head(10)
#
# ...

# %% [markdown]
# ### Filtrando classe Amazônia pelo acumulado total de Milho anual

# %%
def acumulador_milho_amazonia_1999():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 1999 e soma todos os valores
    total_milho_1999 = df_milho_filtrado['1999'].sum()
    
    return total_milho_1999

# %%
def acumulador_milho_amazonia_2000():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2000 e soma todos os valores
    total_milho_2000 = df_milho_filtrado['2000'].sum()
    
    return total_milho_2000

# %%
def acumulador_milho_amazonia_2001():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2001 e soma todos os valores
    total_milho_2001 = df_milho_filtrado['2001'].sum()
    
    return total_milho_2001

# %%
def acumulador_milho_amazonia_2002():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2002 e soma todos os valores
    total_milho_2002 = df_milho_filtrado['2002'].sum()
    
    return total_milho_2002

# %%
def acumulador_milho_amazonia_2003():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2003 e soma todos os valores
    total_milho_2003 = df_milho_filtrado['2003'].sum()
    
    return total_milho_2003

# %%
def acumulador_milho_amazonia_2004():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2004 e soma todos os valores
    total_milho_2004 = df_milho_filtrado['2004'].sum()
    
    return total_milho_2004

# %%
def acumulador_milho_amazonia_2005():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2005 e soma todos os valores
    total_milho_2005 = df_milho_filtrado['2005'].sum()
    
    return total_milho_2005

# %%
def acumulador_milho_amazonia_2006():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2006 e soma todos os valores
    total_milho_2006 = df_milho_filtrado['2006'].sum()
    
    return total_milho_2006

# %%
def acumulador_milho_amazonia_2007():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2007 e soma todos os valores
    total_milho_2007 = df_milho_filtrado['2007'].sum()
    
    return total_milho_2007

# %%
def acumulador_milho_amazonia_2008():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2008 e soma todos os valores
    total_milho_2008 = df_milho_filtrado['2008'].sum()
    
    return total_milho_2008

# %%
def acumulador_milho_amazonia_2009():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2009 e soma todos os valores
    total_milho_2009 = df_milho_filtrado['2009'].sum()
    
    return total_milho_2009

# %%
def acumulador_milho_amazonia_2010():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2010 e soma todos os valores
    total_milho_2010 = df_milho_filtrado['2010'].sum()
    
    return total_milho_2010

# %%
def acumulador_milho_amazonia_2011():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2011 e soma todos os valores
    total_milho_2011 = df_milho_filtrado['2011'].sum()
    
    return total_milho_2011

# %%
def acumulador_milho_amazonia_2012():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2012 e soma todos os valores
    total_milho_2012 = df_milho_filtrado['2012'].sum()
    
    return total_milho_2012

# %%
def acumulador_milho_amazonia_2013():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2013 e soma todos os valores
    total_milho_2013 = df_milho_filtrado['2013'].sum()
    
    return total_milho_2013

# %%
def acumulador_milho_amazonia_2014():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2014 e soma todos os valores
    total_milho_2014 = df_milho_filtrado['2014'].sum()
    
    return total_milho_2014

# %%
def acumulador_milho_amazonia_2015():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2015 e soma todos os valores
    total_milho_2015 = df_milho_filtrado['2015'].sum()
    
    return total_milho_2015

# %%
def acumulador_milho_amazonia_2016():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2016 e soma todos os valores
    total_milho_2016 = df_milho_filtrado['2016'].sum()
    
    return total_milho_2016

# %%
def acumulador_milho_amazonia_2017():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2017 e soma todos os valores
    total_milho_2017 = df_milho_filtrado['2017'].sum()
    
    return total_milho_2017

# %%
def acumulador_milho_amazonia_2018():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2018 e soma todos os valores
    total_milho_2018 = df_milho_filtrado['2018'].sum()
    
    return total_milho_2018

# %%
def acumulador_milho_amazonia_2019():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2019 e soma todos os valores
    total_milho_2019 = df_milho_filtrado['2019'].sum()
    
    return total_milho_2019

# %%
def acumulador_milho_amazonia_2020():
    estados_amazonia = ['Tocantins', 'Roraima', 'Rondônia', 'Pará', 'Mato Grosso',
                        'Maranhão', 'Amapá', 'Amazonas', 'Acre']
    
    # 1. Filtra apenas os estados da Amazônia
    df_milho_filtrado = df_milho[df_milho['Estado'].isin(estados_amazonia)]
    
    # 2. Seleciona a coluna do ano 2020 e soma todos os valores
    total_milho_2020 = df_milho_filtrado['2020'].sum()
    
    return total_milho_2020

# %% [markdown]
# ### Filtrando classe Pará pelo acumulado total de Milho anual

# %%
def acumulador_milho_para_1999():
    """
    Retorna a produção de milho do Pará para o ano de 1999.
    
    Retorno:
        float: Soma da produção de milho do Pará em 1999.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['1999'].sum()

# %%
def acumulador_milho_para_2000():
    """
    Retorna a produção de milho do Pará para o ano de 2000.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2000.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']

    return df_para['2000'].sum()

# %%
def acumulador_milho_para_2001():
    """
    Retorna a produção de milho do Pará para o ano de 2001.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2001.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2001'].sum()

# %%
def acumulador_milho_para_2002():
    """
    Retorna a produção de milho do Pará para o ano de 2002.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2002.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2002'].sum()

# %%
def acumulador_milho_para_2003():
    """
    Retorna a produção de milho do Pará para o ano de 2003.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2003.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    
    
    return df_para['2003'].sum()

# %%
def acumulador_milho_para_2004():
    """
    Retorna a produção de milho do Pará para o ano de 2004.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2004.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2004'].sum()

# %%
def acumulador_milho_para_2005():
    """
    Retorna a produção de milho do Pará para o ano de 2005.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2005.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    
   
    return df_para['2005'].sum()

# %%
def acumulador_milho_para_2006():
    """
    Retorna a produção de milho do Pará para o ano de 2006.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2006.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']

    return df_para['2006'].sum()

# %%
def acumulador_milho_para_2007():
    """
    Retorna a produção de milho do Pará para o ano de 2007.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2007.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2007'].sum()

# %%
def acumulador_milho_para_2008():
    """
    Retorna a produção de milho do Pará para o ano de 2008.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2008.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2008'].sum()

# %%
def acumulador_milho_para_2009():
    """
    Retorna a produção de milho do Pará para o ano de 2009.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2009.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2009'].sum()

# %%
def acumulador_milho_para_2010():
    """
    Retorna a produção de milho do Pará para o ano de 2010.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2010.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2010'].sum()

# %%
def acumulador_milho_para_2011():
    """
    Retorna a produção de milho do Pará para o ano de 2011.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2011.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2011'].sum()

# %%
def acumulador_milho_para_2012():
    """
    Retorna a produção de milho do Pará para o ano de 2012.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2012.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2012'].sum()

# %%
def acumulador_milho_para_2013():
    """
    Retorna a produção de milho do Pará para o ano de 2013.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2013.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2013'].sum()

# %%
def acumulador_milho_para_2014():
    """
    Retorna a produção de milho do Pará para o ano de 2014.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2014.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2014'].sum()

# %%
def acumulador_milho_para_2015():
    """
    Retorna a produção de milho do Pará para o ano de 2015.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2015.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2015'].sum()

# %%
def acumulador_milho_para_2016():
    """
    Retorna a produção de milho do Pará para o ano de 2016.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2016.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2016'].sum()

# %%
def acumulador_milho_para_2017():
    """
    Retorna a produção de milho do Pará para o ano de 2017.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2017.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2017'].sum()

# %%
def acumulador_milho_para_2018():
    """
    Retorna a produção de milho do Pará para o ano de 2018.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2018.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2018'].sum()

# %%
def acumulador_milho_para_2019():
    """
    Retorna a produção de milho do Pará para o ano de 2019.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2019.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2019'].sum()

# %%
def acumulador_milho_para_2020():
    """
    Retorna a produção de milho do Pará para o ano de 2020.
    
    Retorno:
        float: Soma da produção de milho do Pará em 2020.
    """
    # Filtra apenas o estado do Pará
    df_para = df_milho[df_milho['Estado'] == 'Pará']
    

    return df_para['2020'].sum()

# %% [markdown]
# ## Necessário criar listas com os valores anuais para cada função:

# %%
import matplotlib.pyplot as plt

# Lista de anos (colunas do DataFrame)
anos = [str(ano) for ano in range(1999, 2021)]  # 1999 a 2020

# Dados do Pará
producao_para = []
for ano in anos:
    try:
        # Chama cada função acumulador_milho_para_XXXX()
        valor = eval(f"acumulador_milho_para_{ano}()")  # Nota: eval pode ser inseguro - veja alternativa abaixo
        producao_para.append(valor)
    except:
        producao_para.append(0)  # Caso a função/ano não exista

# Dados da Amazônia
producao_amazonia = []
for ano in anos:
    try:
        # Chama cada função acumulador_milho_amazonia_{ano}()
        valor = eval(f"acumulador_milho_amazonia_{ano}()")
        producao_amazonia.append(valor)
    except:
        producao_amazonia.append(0)

# %%
# Geração da lista de anos (como strings)
anos = [str(ano) for ano in range(1999, 2021)]  # 1999 a 2020 (inclusive)

# Verificação (para provar que funciona)
print("Anos gerados:", anos)
print("Total de anos:", len(anos))
print("Primeiro ano:", anos[0])
print("Último ano:", anos[-1])
# Out:
# Anos gerados: ['1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']
# Total de anos: 22
# Primeiro ano: 1999
# Último ano: 2020

# %% [markdown]
# ##  Criação do gráfico

# %%
# Configuração do gráfico
plt.figure(figsize=(15, 6))
bar_width = 0.35
indices = range(len(anos))

# Barras para o Pará
plt.bar(
    [i - bar_width/2 for i in indices],
    producao_para,
    width=bar_width,
    label='Pará',
    color='#1f77b4'
)

# Barras para a Amazônia
plt.bar(
    [i + bar_width/2 for i in indices],
    producao_amazonia,
    width=bar_width,
    label='Amazônia',
    color='#ff7f0e'
)

# Formatação
plt.title('Produção de Milho: Pará vs. Amazônia (1999-2020)')
plt.xlabel('Ano')
plt.ylabel('Rendimento (R$)')
plt.xticks(indices, anos, rotation=45)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Exibir
plt.tight_layout()
plt.show()
